# %%
install.packages('mcsm', repos='http://cran.us.r-project.org')
# Out:
# package 'mcsm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\ASUS\AppData\Local\Temp\RtmpC81WJ5\downloaded_packages

# %%
library('MASS')
library('mcsm')

# %%
data('challenger')
head(challenger)
# Out:
#   oring temp
# 1 1     53
# 2 1     57
# 3 1     58
# 4 1     63
# 5 0     66
# 6 0     67

# %%
oring<-challenger[['oring']]
temp<-challenger[['temp']]
model1 <- glm(oring ~ temp, binomial)
# summary(model1)
# test_set<-set(60,50,40)

# new <- data.frame(temp = c(60, 50, 40))
# y<-predict(model1, newdata = new, type ='response')
# y
summary(model1)
# Out:
# Call:
# glm(formula = oring ~ temp, family = binomial)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.0611  -0.7613  -0.3783   0.4524   2.2175
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  15.0429     7.3786   2.039   0.0415 *
# temp         -0.2322     0.1082  -2.145   0.0320 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 28.267  on 22  degrees of freedom
# Residual deviance: 20.315  on 21  degrees of freedom
# AIC: 24.315
#
# Number of Fisher Scoring iterations: 5

# %%
# x0<-rnorm(1,0,1)
x0<-0
X<-c(x0)
xt<-x0
for (i in seq(1,10000,length=10000)){
    xt = xt + rnorm(1,0,1)
    X<-c(X, xt)
}
print('Done!^')
# Out:
# [1] "Done!^"

# %%
til<-10000
plot(seq(0,til-1,by=1),X[1:til])
lines(seq(0,til-1,by=1),X[1:til])
# Out:
# plot without title

# %%
hist(X)
# Out:
# Plot with title "Histogram of X"

# %%
Y<-rnorm(10000,0,1/(1-0.81))
hist(Y)
# Out:
# Plot with title "Histogram of Y"
